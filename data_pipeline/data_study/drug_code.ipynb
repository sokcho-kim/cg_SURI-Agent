# %%
import pandas as pd 

df = pd.read_csv("./건강보험심사평가원_약가마스터_의약품표준코드_20241014.csv", encoding='cp949')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298183 entries, 0 to 298182
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   한글상품명         298183 non-null  object
#  1   업체명           298183 non-null  object
#  2   약품규격          298148 non-null  object
#  3   제품총수량         298183 non-null  int64
#  4   제형구분          190892 non-null  object
#  5   포장형태          190884 non-null  object
#  6   품목기준코드        298183 non-null  int64
#  7   품목허가일자        297480 non-null  object
#  8   전문_일반         286397 non-null  object
#  9   대표코드          298183 non-null  int64
#  10  표준코드          298183 non-null  int64
#  11  제품코드(개정후)     68100 non-null   float64
#  12  일반명코드(성분명코드)  137526 non-null  object
#  13  비고            87926 non-null   object
#  14  취소일자          69823 non-null   object
#  15  양도양수적용(공고)일자  43480 non-null   object
#  16  양도양수종료일자      21309 non-null   object
# ...
